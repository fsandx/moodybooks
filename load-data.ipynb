# %%
import pandas as pd
reviews = pd.read_json('data/reviews.json')
reviews
# Out:
#     number                                             author  \
# 0      100                              by Nora Ephron (2006)
# 1       99  by Alain Mabanckou (2005), translated by Helen...
# 2       98  by Stieg Larsson (2005), translated by Steven ...
# 3       97                               by JK Rowling (2000)
# 4       96                         by Hanya Yanagihara (2015)
# ..     ...                                                ...
# 79       6                           by Philip Pullman (2000)
# 80       5  by WG Sebald (2001), translated by Anthea Bell...
# 81       4                           by Kazuo Ishiguro (2005)
# 82       2                       by Marilynne Robinson (2004)
# 83       1                            by Hilary Mantel (2009)
#
#                                   title  \
# 0              I Feel Bad About My Neck
# 1                          Broken Glass
# 2                             The Girl
# 3   Harry Potter and the Goblet of Fire
# ...

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   number  84 non-null     int64
#  1   author  84 non-null     object
#  2   title   84 non-null     object
#  3   url     84 non-null     object
#  4   text    84 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 3.4+ KB

# %%
import pandas as pd
mwords = pd.read_csv('data/moodywoords.csv')
mwords
# Out:
#    Book Id  admiration  adoration  aesthetic appreciation  amusement  anger  \
# 0    11111           0          0                       0          0      0
#
#    anxiety  awe  awkwardness  boredom  ...  horror  interest  joy  nostalgia  \
# 0        0    0            0        0  ...       0         0    0          0
#
#    relief  romance  sadness  satisfaction  sexual desire  surprise
# 0       0        0        0             0              0         0
#
# [1 rows x 28 columns]

# %%
import WordCounter as wc
inst = wc.WordCounter()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_209164/4012434633.py in <module>
#       1 import WordCounter as wc
# ----> 2 inst = wc.WordCounter()
#
# ~/dev/mda512/moodybooks/WordCounter.py in __init__(self)
#      16         reviews = pd.read_json(REVIEWS_PATH)
#      17         words = pd.read_csv(WORDS_PATH)
# ---> 18         print(reviews.info())
#      19         print(words.info())
#
# AttributeError: 'WordCounter' object has no attribute 'countWords'
